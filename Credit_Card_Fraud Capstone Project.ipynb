# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df[df['Class'] == 0].Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
df[df['Class'] == 1].Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# From the above observations the fraudulent transactions are having higher
# Mean then the non-fradulent transactions

# %%
# Correlation matrix 
corrmat = df.corr() 
fig = plt.figure(figsize = (12, 9)) 
sns.heatmap(corrmat, vmax = .8, square = True) 
plt.show()

# %% [markdown]
# There is no correlatin between two features
# (V2,Amount) and (V5,Amount) are negatively correlated

# %%
x = df.drop(['Class'], axis = 1) 
y = df["Class"]

# %%
y.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# The Target feature is having unbalanced data as Fradulent Transaction are
# very less compared to Non-Fradulent Transactions

# %%
# To balance the data we generate the data using balancing techniques
from imblearn.over_sampling import SMOTE
# Resampling the minority class
sm = SMOTE(sampling_strategy='minority', random_state=42)
# Fit the model to generate the data.
x, y = sm.fit_resample(x, y)

# %%
# splitting the dataset into test and train data
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# ------------------------------
from sklearn.metrics import classification_report, accuracy_score 
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import f1_score, matthews_corrcoef 
from sklearn.metrics import confusion_matrix 


# defined models
models = {
    'Logistic_Regression' : LogisticRegression(random_state=0,max_iter=1000),
    'KNeighnorsClassifier' : KNeighborsClassifier(n_neighbors=3),
    'Decision Tree Classifier' : DecisionTreeClassifier(),
    'SGDC Classifier' : make_pipeline(StandardScaler(),SGDClassifier(max_iter=1000, tol=1e-3)),
    'RandomForest Classifier' : RandomForestClassifier(random_state=0)
}

accuracy_results = pd.DataFrame(columns = ['Model','Accuracy'])
accuracy_append = []

for model_name,model in models.items():
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    accuracy_append.append(accuracy)
    
    print(f"{model_name}")
    
    accuracy = accuracy_score(y_test,y_pred)
    print(f"The Accuracy for {model_name}  : {accuracy}")

    prec = precision_score(y_test, y_pred) 
    print(f"The precision for {model_name} : {accuracy}") 

    rec = recall_score(y_test, y_pred) 
    print(f"The recall is for {model_name} : {accuracy}") 

    f1 = f1_score(y_test, y_pred) 
    print(f"The F1-Score for {model_name}  : {accuracy}")
    print("-------------------------------------------------------")



accuracy_results = pd.concat([pd.Series(models.keys()),pd.Series(accuracy_append)],keys=['Model','Accuracy'],axis=1,ignore_index=True)
accuracy_results.rename(columns = {0:'Model Name',1:'Accuracy'}, inplace = True)

print(accuracy_results)
# Out:
# Logistic_Regression
# The Accuracy for Logistic_Regression  : 0.9736501181201601
# The precision for Logistic_Regression : 0.9736501181201601
# The recall is for Logistic_Regression : 0.9736501181201601
# The F1-Score for Logistic_Regression  : 0.9736501181201601
# -------------------------------------------------------
# KNeighnorsClassifier
# The Accuracy for KNeighnorsClassifier  : 0.9681515220793838
# The precision for KNeighnorsClassifier : 0.9681515220793838
# The recall is for KNeighnorsClassifier : 0.9681515220793838
# The F1-Score for KNeighnorsClassifier  : 0.9681515220793838
# -------------------------------------------------------
# Decision Tree Classifier
# The Accuracy for Decision Tree Classifier  : 0.9980362156997227
# The precision for Decision Tree Classifier : 0.9980362156997227
# The recall is for Decision Tree Classifier : 0.9980362156997227
# The F1-Score for Decision Tree Classifier  : 0.9980362156997227
# ...

# %% [markdown]
# As per above models RANDOMFOREST CLASSIFIER is best model to predict
# whether the trasanction is fraulent or not

# %%
import matplotlib.pyplot as plt
from sklearn import metrics

actual = y_test
predicted = y_pred

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [True,False])

cm_display.plot()
plt.show()

# %%
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(y_test, y_pred, multi_class='ovr')
print(f'ROC AUC SCORE : {roc_auc}')
# Out:
# ROC AUC SCORE : 0.99989432292745

# %% [markdown]
# ROC AUC SCORE is near to 1 so that the model is performing best

# %%
# function to find best feature will be highlighted and
# will considered as most powerful feature to use for modelling in random forest
def highlight_most_important_feature(feature_score):
    most_important = feature_score.idmax()
    return ['backgroundcolor : yellow' if col == most_important else '' for col in feature_score.index]

feature_importance = pd.Series(model.feature_importances_,index=x_train.columns).sort_values(ascending = False)

# %%
feature_importance.sort_values(ascending=False)
# Out:
# V14       0.240735
# V10       0.177145
# V4        0.108932
# V12       0.100817
# V11       0.066957
# V16       0.050044
# V3        0.048357
# V17       0.034182
# V2        0.027920
# V7        0.017973
# V9        0.015989
# V6        0.012303
# V21       0.010314
# V18       0.010246
# V1        0.009931
# V8        0.008332
# Time      0.007962
# V5        0.006065
# V27       0.005322
# V13       0.004902
# V19       0.004077
# V28       0.003942
# V20       0.003844
# Amount    0.003762
# V23       0.003643
# V15       0.003523
# V26       0.003522
# V22       0.003320
# V25       0.003119
# V24       0.002821
# dtype: float64

# %% [markdown]
# From the above observation the most important feature in the dataset is V14
# The Least important feature is V24
